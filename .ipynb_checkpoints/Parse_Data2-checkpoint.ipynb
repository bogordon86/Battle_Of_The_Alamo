# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
# get data file names
path =r'C:\Users\BenG\Documents\GitHub\Battle_Of_The_Alamo'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
auth4_data = pd.concat(dfs, ignore_index=True)

# %%
#Initial Inspection of Dataframe 
auth4_data.head()
# Out:
#      time src_user@dom dst_user@dom src_comp dst_comp auth_type logon_type  \
# 0  726131   U9040@DOM1   U9040@DOM1   C19193     C625         ?          ?
# 1  726131   U9040@DOM1   U9040@DOM1   C19193     C625  Kerberos    Network
# 2  726131   U9040@DOM1   U9040@DOM1     C529     C529         ?    Network
# 3  726131   U9040@DOM1   U9040@DOM1     C625     C625         ?    Network
# 4  726131   U9093@DOM1   U9093@DOM1   C19290     C529  Kerberos    Network
#
#   auth_orientation succ_fail
# 0              TGS   Success
# 1            LogOn   Success
# 2           LogOff   Success
# 3           LogOff   Success
# 4            LogOn   Success

# %%
#Convert ? to standard NaN for further processing
auth4_clean= auth4_data.replace('?', np.NaN)
auth4_clean.head()
# Out:
#      time src_user@dom dst_user@dom src_comp dst_comp auth_type logon_type  \
# 0  726131   U9040@DOM1   U9040@DOM1   C19193     C625       NaN        NaN
# 1  726131   U9040@DOM1   U9040@DOM1   C19193     C625  Kerberos    Network
# 2  726131   U9040@DOM1   U9040@DOM1     C529     C529       NaN    Network
# 3  726131   U9040@DOM1   U9040@DOM1     C625     C625       NaN    Network
# 4  726131   U9093@DOM1   U9093@DOM1   C19290     C529  Kerberos    Network
#
#   auth_orientation succ_fail
# 0              TGS   Success
# 1            LogOn   Success
# 2           LogOff   Success
# 3           LogOff   Success
# 4            LogOn   Success

# %%
#Remove rows with NaN and reset index for new dataframe
auth4_drop = auth4_clean.dropna()
auth4_index = auth4_drop.reset_index(drop=True)
auth4_index.head()
# Out:
#      time src_user@dom dst_user@dom src_comp dst_comp auth_type logon_type  \
# 0  726131   U9040@DOM1   U9040@DOM1   C19193     C625  Kerberos    Network
# 1  726131   U9093@DOM1   U9093@DOM1   C19290     C529  Kerberos    Network
# 2  726131   U9093@DOM1   U9093@DOM1   C19290     C586  Kerberos    Network
# 3  726131   U9136@DOM1   U9136@DOM1   C19359    C5618      NTLM    Network
# 4  726131   U9292@DOM1   U9292@DOM1   C19632    C2162  Kerberos    Network
#
#   auth_orientation succ_fail
# 0            LogOn   Success
# 1            LogOn   Success
# 2            LogOn   Success
# 3            LogOn   Success
# 4            LogOn   Success

# %%
#Split apart src_user + dst_user in train data for relevant info
auth4_index[['src_user', 'dom']] = auth4_index['src_user@dom'].str.split('@', expand=True)
auth4_index[['dst_user', 'dom2']] = auth4_index['dst_user@dom'].str.split('@', expand=True)

# %%
#Checking out multiple columns for how many values would encode to binary
#auth4_index['src_comp'].value_counts()
#auth4_index['dst_comp'].value_counts()
match = auth4_index.apply(lambda x: x['src_user'] != x['dst_user'], axis=1)
match.value_counts()
# Out:
# False    4397616
# True      127174
# dtype: int64

# %%
#Inspect the src_comp and dst_comp columns for duplicates
match2 = auth4_index.apply(lambda x: x['src_comp'] != x['dst_comp'], axis=1)
match2.value_counts()
# Out:
# True     4002908
# False     521882
# dtype: int64

# %%
.to_csv('auth4_training.csv')
